# %%
# import libraries
import urllib3
import urllib.parse
from bs4 import BeautifulSoup
import csv
import re

# %%
base_url = 'http://www.uz.gov.ua/passengers/timetable/'
station_url_pre = '?station='
station_url_post = '&by_station='+ urllib.parse.quote('Пошук', safe='')
train_url_pre = '?ntrain='
train_url_post = '&by_id=1'
stations = [['47548,23092,23081,23215,36921,23200', 'Львів'], ['23020', 'Ковель'], 
            ['23300', 'Тернопіль'], ['23600,23629', 'Одеса'], ['22423', 'Шевченкове'], 
            ['23390', 'Знам\'янка'], ['23536', 'Миколаїв'], ['22700', 'Дніпро'], 
            ['22680,22900,22840,22747', 'Кривий Ріг'], ['22730,22800', 'Запоріжжя'], 
            ['739,47125,22080,47140,47175,22298,22000,47190', 'Київ'], ['22070', 'Ніжин'], 
            ['22270', 'Жмеринка'], ['22302', 'Козятин-1'], ['22171', 'Козятин-2'], 
            ['22100,22446,22410', 'Харків'], ['22430', 'Лозова'], 
            ['22580,22590', 'Полтава'], ['22450', 'Суми']]

# %%
def processStation(station_id, station_name):
    print('Processing station: '+station_name+' - start')
    http = urllib3.PoolManager()
    station_url_full = base_url + station_url_pre + station_id + station_url_post
    print('GET url: '+station_url_full)
    request = http.request('GET', station_url_full)
    soup = BeautifulSoup(request.data, 'html5lib')
    
    trains = []
    trains_div = soup.find('div', attrs={'class':'c-trains-by-station'})
    trains_table = trains_div.find('table')
    trains_table_body = trains_table.find('tbody')
    train_rows = trains_table_body.find_all('tr')
    for row in train_rows:
        cols = row.find_all('td')
        a = cols[0].find_all('a', href=True)
        match = re.match('\?ntrain=(.+)&by_id=1', a[0]['href'])
        train_id = match.group(1)
        train_name = a[0].text.strip()
        trains.append([train_id, train_name])
    print(len(trains),' trains parsed')
    csv_file_name = 'node_stations\'+station_name+'.csv'
    with open(csv_file_name, 'w', newline='', encoding = "utf-8") as csv_file:        
        writer = csv.writer(csv_file)
        for row in trains:
            writer.writerow(row)
    print('Trains table saved to file: '+csv_file_name)
    print('Processing station: '+station_name+' - done')
    return trains

# %%
all_trains = []

for station in stations:
    trains = processStation(station[0], station[1])
    all_trains.extend(trains)
# Out:
# Processing station: Львів - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?station=47548,23092,23081,23215,36921,23200&by_station=%D0%9F%D0%BE%D1%88%D1%83%D0%BA
# 214  trains parsed
# Trains table saved to file: Львів.csv
# Processing station: Львів - done
# Processing station: Ковель - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?station=23020&by_station=%D0%9F%D0%BE%D1%88%D1%83%D0%BA
# 26  trains parsed
# Trains table saved to file: Ковель.csv
# Processing station: Ковель - done
# Processing station: Тернопіль - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?station=23300&by_station=%D0%9F%D0%BE%D1%88%D1%83%D0%BA
# 84  trains parsed
# Trains table saved to file: Тернопіль.csv
# Processing station: Тернопіль - done
# Processing station: Одеса - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?station=23600,23629&by_station=%D0%9F%D0%BE%D1%88%D1%83%D0%BA
# 90  trains parsed
# Trains table saved to file: Одеса.csv
# Processing station: Одеса - done
# Processing station: Шевченкове - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?station=22423&by_station=%D0%9F%D0%BE%D1%88%D1%83%D0%BA
# 9  trains parsed
# Trains table saved to file: Шевченкове.csv
# Processing station: Шевченкове - done
# Processing station: Знам'янка - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?station=23390&by_station=%D0%9F%D0%BE%D1%88%D1%83%D0%BA
# 81  trains parsed
# Trains table saved to file: Знам'янка.csv
# Processing station: Знам'янка - done
# Processing station: Миколаїв - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?station=23536&by_station=%D0%9F%D0%BE%D1%88%D1%83%D0%BA
# 29  trains parsed
# Trains table saved to file: Миколаїв.csv
# Processing station: Миколаїв - done
# Processing station: Дніпро - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?station=22700&by_station=%D0%9F%D0%BE%D1%88%D1%83%D0%BA
# 64  trains parsed
# Trains table saved to file: Дніпро.csv
# Processing station: Дніпро - done
# Processing station: Кривий Ріг - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?station=22680,22900,22840,22747&by_station=%D0%9F%D0%BE%D1%88%D1%83%D0%BA
# 41  trains parsed
# Trains table saved to file: Кривий Ріг.csv
# Processing station: Кривий Ріг - done
# Processing station: Запоріжжя - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?station=22730,22800&by_station=%D0%9F%D0%BE%D1%88%D1%83%D0%BA
# 66  trains parsed
# Trains table saved to file: Запоріжжя.csv
# Processing station: Запоріжжя - done
# Processing station: Київ - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?station=739,47125,22080,47140,47175,22298,22000,47190&by_station=%D0%9F%D0%BE%D1%88%D1%83%D0%BA
# 438  trains parsed
# Trains table saved to file: Київ.csv
# Processing station: Київ - done
# Processing station: Ніжин - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?station=22070&by_station=%D0%9F%D0%BE%D1%88%D1%83%D0%BA
# 57  trains parsed
# Trains table saved to file: Ніжин.csv
# Processing station: Ніжин - done
# Processing station: Жмеринка - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?station=22270&by_station=%D0%9F%D0%BE%D1%88%D1%83%D0%BA
# 98  trains parsed
# Trains table saved to file: Жмеринка.csv
# Processing station: Жмеринка - done
# Processing station: Козятин-1 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?station=22302&by_station=%D0%9F%D0%BE%D1%88%D1%83%D0%BA
# 125  trains parsed
# Trains table saved to file: Козятин-1.csv
# Processing station: Козятин-1 - done
# Processing station: Козятин-2 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?station=22171&by_station=%D0%9F%D0%BE%D1%88%D1%83%D0%BA
# 3  trains parsed
# Trains table saved to file: Козятин-2.csv
# Processing station: Козятин-2 - done
# Processing station: Харків - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?station=22100,22446,22410&by_station=%D0%9F%D0%BE%D1%88%D1%83%D0%BA
# 126  trains parsed
# Trains table saved to file: Харків.csv
# Processing station: Харків - done
# Processing station: Лозова - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?station=22430&by_station=%D0%9F%D0%BE%D1%88%D1%83%D0%BA
# 31  trains parsed
# Trains table saved to file: Лозова.csv
# Processing station: Лозова - done
# Processing station: Полтава - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?station=22580,22590&by_station=%D0%9F%D0%BE%D1%88%D1%83%D0%BA
# 75  trains parsed
# Trains table saved to file: Полтава.csv
# Processing station: Полтава - done
# Processing station: Суми - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?station=22450&by_station=%D0%9F%D0%BE%D1%88%D1%83%D0%BA
# 43  trains parsed
# Trains table saved to file: Суми.csv
# Processing station: Суми - done

# %%
dup_n = 0
all_trains_dict = {}
for train in all_trains:
    key = train[0].strip()
    value = train[1].strip()
    if key in all_trains_dict:
        dup_n = dup_n + 1
    else:
      all_trains_dict[key] = value

print(dup_n, ' duplications of trains in node stations, ', len(all_trains_dict.keys()), 'unique trains')
# Out:
# 1219  duplications of trins in node stations,  481 unique trains

# %%
# Out:
# All trains table saved to file: trains_all.csv

# %%
def processTrain(train_id, train_name):
    print('Processing train: '+train_name+' - start')
    http = urllib3.PoolManager()
    train_url_full = base_url + train_url_pre + train_id + train_url_post
    print('GET url: '+train_url_full)
    request = http.request('GET', train_url_full)
    soup = BeautifulSoup(request.data, 'html5lib')
    
    train_div = soup.find('div', attrs={'class':'c-trains-by-number'})
    train_table = train_div.find_all('table')[0]
    cols = train_table.find_all('td')
    train = [train_id,cols[1].text.strip(),cols[0].text.strip(),cols[2].text.strip(),cols[3].text.strip()]
    
    stops = []
    stops_table = train_div.find_all('table')[1]    
    stops_table_body = stops_table.find('tbody')
    stops_rows = stops_table_body.find_all('tr')
    for row in stops_rows:
        cols = row.find_all('td')
        
        a = cols[0].find_all('a', href=True)
        match = re.match('\?station=(.+)&by_station=1', a[0]['href'])
        station_id = match.group(1)
        station_name = a[0].text.strip()
        time_arrive = cols[1].text.strip()
        time_departure = cols[2].text.strip()
        stops.append([station_id, station_name, time_arrive, time_departure])
    print(len(trains),' trains parsed')
    csv_file_name = 'trains/'+train_id+'.csv'
    with open(csv_file_name, 'w', newline='', encoding = "utf-8") as csv_file:        
        writer = csv.writer(csv_file)
        for row in stops:
            writer.writerow(row)
    print('Trains table saved to file: '+csv_file_name)
    print('Processing train: '+train_name+' - done')
    return train, stops

# %%
all_trains = []
all_stops_dict = {}
for key in all_trains_dict.keys():
    train, stops = processTrain(key, all_trains_dict[key])
    all_trains.append(train)
    all_stops_dict[train[0]] = stops
# Out:
# Processing train: 43 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56927&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56927.csv
# Processing train: 43 - done
# Processing train: 133 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=1668&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/1668.csv
# Processing train: 133 - done
# Processing train: 250 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57110&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57110.csv
# Processing train: 250 - done
# Processing train: 749  (ІНТЕРСІТІ) - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=54178&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/54178.csv
# Processing train: 749  (ІНТЕРСІТІ) - done
# Processing train: 7 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=429&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/429.csv
# Processing train: 7 - done
# Processing train: 233 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57065&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57065.csv
# Processing train: 233 - done
# Processing train: 193 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57095&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57095.csv
# Processing train: 193 - done
# Processing train: 218 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57107&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57107.csv
# Processing train: 218 - done
# Processing train: 43 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56758&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56758.csv
# Processing train: 43 - done
# Processing train: 1 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56805&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56805.csv
# Processing train: 1 - done
# Processing train: 136 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=423&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/423.csv
# Processing train: 136 - done
# Processing train: 34 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=54219&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/54219.csv
# Processing train: 34 безпересадковий вагон - done
# Processing train: 147 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56850&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56850.csv
# Processing train: 147 безпересадковий вагон - done
# Processing train: 144 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=2072&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/2072.csv
# Processing train: 144 - done
# Processing train: 63170 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57009&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57009.csv
# Processing train: 63170 - done
# Processing train: 53170 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57012&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57012.csv
# Processing train: 53170 безпересадковий вагон - done
# Processing train: 743  (ІНТЕРСІТІ+) - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56810&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56810.csv
# Processing train: 743  (ІНТЕРСІТІ+) - done
# Processing train: 295 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57133&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57133.csv
# Processing train: 295 - done
# Processing train: 232 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57099&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57099.csv
# Processing train: 232 - done
# Processing train: 275 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=1354&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/1354.csv
# Processing train: 275 - done
# Processing train: 41 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=386&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/386.csv
# Processing train: 41 - done
# Processing train: 69 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57060&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57060.csv
# Processing train: 69 безпересадковий вагон - done
# Processing train: 69 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57059&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57059.csv
# Processing train: 69 безпересадковий вагон - done
# Processing train: 232 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57120&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57120.csv
# Processing train: 232 безпересадковий вагон - done
# Processing train: 232 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57063&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57063.csv
# Processing train: 232 - done
# Processing train: 120 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=134&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/134.csv
# Processing train: 120 - done
# Processing train: 811 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56874&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56874.csv
# Processing train: 811 - done
# Processing train: 7 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57129&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57129.csv
# Processing train: 7 - done
# Processing train: 749  (ІНТЕРСІТІ) - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=54166&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/54166.csv
# Processing train: 749  (ІНТЕРСІТІ) - done
# Processing train: 7 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=54177&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/54177.csv
# Processing train: 7 - done
# Processing train: 749 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56849&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56849.csv
# Processing train: 749 безпересадковий вагон - done
# Processing train: 141 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=136&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/136.csv
# Processing train: 141 - done
# Processing train: 13 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56631&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56631.csv
# Processing train: 13 - done
# Processing train: 13 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57055&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57055.csv
# Processing train: 13 - done
# Processing train: 49  ("КОБЗАР") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=1296&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/1296.csv
# Processing train: 49  ("КОБЗАР") - done
# Processing train: 81  ("ДЕСНА") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56969&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56969.csv
# Processing train: 81  ("ДЕСНА") - done
# Processing train: 29 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56826&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56826.csv
# Processing train: 29 - done
# Processing train: 29 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57109&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57109.csv
# Processing train: 29 - done
# Processing train: 29 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57006&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57006.csv
# Processing train: 29 - done
# Processing train: 207 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=1947&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/1947.csv
# Processing train: 207 - done
# Processing train: 81  ("ДЕСНА") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=1289&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/1289.csv
# Processing train: 81  ("ДЕСНА") - done
# Processing train: 249 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56846&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56846.csv
# Processing train: 249 - done
# Processing train: 44 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56928&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56928.csv
# Processing train: 44 - done
# Processing train: 13 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57058&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57058.csv
# Processing train: 13 безпересадковий вагон - done
# Processing train: 13 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=54312&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/54312.csv
# Processing train: 13 безпересадковий вагон - done
# Processing train: 217 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=54172&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/54172.csv
# Processing train: 217 - done
# Processing train: 219 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56848&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56848.csv
# Processing train: 219 - done
# Processing train: 715  (ІНТЕРСІТІ+) - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56175&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56175.csv
# Processing train: 715  (ІНТЕРСІТІ+) - done
# Processing train: 143 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=54169&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/54169.csv
# Processing train: 143 - done
# Processing train: 191 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=51900&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/51900.csv
# Processing train: 191 - done
# Processing train: 243 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=55126&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/55126.csv
# Processing train: 243 - done
# Processing train: 91  ("ЛЬВІВ") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57132&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57132.csv
# Processing train: 91  ("ЛЬВІВ") - done
# Processing train: 755  ("ЛЬВІВ") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57122&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57122.csv
# Processing train: 755  ("ЛЬВІВ") - done
# Processing train: 91  ("ЛЬВІВ") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=54753&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/54753.csv
# Processing train: 91  ("ЛЬВІВ") - done
# Processing train: 239 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=1480&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/1480.csv
# Processing train: 239 - done
# Processing train: 705  (ІНТЕРСІТІ+) - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=54730&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/54730.csv
# Processing train: 705  (ІНТЕРСІТІ+) - done
# Processing train: 668 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=2424&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/2424.csv
# Processing train: 668 - done
# Processing train: 2 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57023&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57023.csv
# Processing train: 2 - done
# Processing train: 2 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56786&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56786.csv
# Processing train: 2 - done
# Processing train: 8813 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=54330&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/54330.csv
# Processing train: 8813 безпересадковий вагон - done
# Processing train: 8813 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57057&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57057.csv
# Processing train: 8813 безпересадковий вагон - done
# Processing train: 234 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57064&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57064.csv
# Processing train: 234 - done
# Processing train: 46 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=352&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/352.csv
# Processing train: 46 - done
# Processing train: 46 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57131&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57131.csv
# Processing train: 46 - done
# Processing train: 46 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56981&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56981.csv
# Processing train: 46 - done
# Processing train: 132  ("СЛОБОЖАНЩИНА") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56972&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56972.csv
# Processing train: 132  ("СЛОБОЖАНЩИНА") - done
# Processing train: 132  ("СЛОБОЖАНЩИНА") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=20&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/20.csv
# Processing train: 132  ("СЛОБОЖАНЩИНА") - done
# Processing train: 112   ("СЛОБОЖАНЩИНА") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56971&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56971.csv
# Processing train: 112   ("СЛОБОЖАНЩИНА") - done
# Processing train: 112   ("СЛОБОЖАНЩИНА") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=207&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/207.csv
# Processing train: 112   ("СЛОБОЖАНЩИНА") - done
# Processing train: 806 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56883&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56883.csv
# Processing train: 806 - done
# Processing train: 110 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=394&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/394.csv
# Processing train: 110 - done
# Processing train: 110 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57035&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57035.csv
# Processing train: 110 - done
# Processing train: 804 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56894&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56894.csv
# Processing train: 804 - done
# Processing train: 372 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56825&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56825.csv
# Processing train: 372 - done
# Processing train: 142 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=205&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/205.csv
# Processing train: 142 - done
# Processing train: 462 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57092&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57092.csv
# Processing train: 462 - done
# Processing train: 827 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56882&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56882.csv
# Processing train: 827 - done
# Processing train: 168 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57103&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57103.csv
# Processing train: 168 - done
# Processing train: 228 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=218&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/218.csv
# Processing train: 228 - done
# Processing train: 258 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=37&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/37.csv
# Processing train: 258 - done
# Processing train: 601 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=28980&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/28980.csv
# Processing train: 601 - done
# Processing train: 829 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56860&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56860.csv
# Processing train: 829 - done
# Processing train: 96  ("ТЯСМИН") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=155&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/155.csv
# Processing train: 96  ("ТЯСМИН") - done
# Processing train: 744  (ІНТЕРСІТІ+) - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=1295&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/1295.csv
# Processing train: 744  (ІНТЕРСІТІ+) - done
# Processing train: 812 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56910&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56910.csv
# Processing train: 812 - done
# Processing train: 12  ("ЗАХІДНИЙ ЕКСПРЕС") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56640&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56640.csv
# Processing train: 12  ("ЗАХІДНИЙ ЕКСПРЕС") - done
# Processing train: 702 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=1279&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/1279.csv
# Processing train: 702 - done
# Processing train: 276 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=1355&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/1355.csv
# Processing train: 276 - done
# Processing train: 194 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57096&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57096.csv
# Processing train: 194 - done
# Processing train: 81 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=54353&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/54353.csv
# Processing train: 81 безпересадковий вагон - done
# Processing train: 74 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=264&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/264.csv
# Processing train: 74 - done
# Processing train: 185 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56842&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56842.csv
# Processing train: 185 - done
# Processing train: 51 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57010&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57010.csv
# Processing train: 51 - done
# Processing train: 51 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57011&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57011.csv
# Processing train: 51 безпересадковий вагон - done
# Processing train: 86 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=379&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/379.csv
# Processing train: 86 - done
# Processing train: 286 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57088&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57088.csv
# Processing train: 286 - done
# Processing train: 92  ("ЛЬВІВ") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=201&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/201.csv
# Processing train: 92  ("ЛЬВІВ") - done
# Processing train: 756  ("ЛЬВІВ") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57123&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57123.csv
# Processing train: 756  ("ЛЬВІВ") - done
# Processing train: 192 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=51901&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/51901.csv
# Processing train: 192 - done
# Processing train: 244 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56428&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56428.csv
# Processing train: 244 - done
# Processing train: 120 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=230&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/230.csv
# Processing train: 120 - done
# Processing train: 70 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=345&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/345.csv
# Processing train: 70 - done
# Processing train: 81 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57061&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57061.csv
# Processing train: 81 безпересадковий вагон - done
# Processing train: 606 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=38380&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/38380.csv
# Processing train: 606 - done
# Processing train: 606 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57015&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57015.csv
# Processing train: 606 - done
# Processing train: 145 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56765&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56765.csv
# Processing train: 145 - done
# Processing train: 461 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57091&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57091.csv
# Processing train: 461 - done
# Processing train: 70 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=236&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/236.csv
# Processing train: 70 - done
# Processing train: 134 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56798&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56798.csv
# Processing train: 134 - done
# Processing train: 371 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=417&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/417.csv
# Processing train: 371 - done
# Processing train: 73 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=330&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/330.csv
# Processing train: 73 - done
# Processing train: 828 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56914&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56914.csv
# Processing train: 828 - done
# Processing train: 86 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=252&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/252.csv
# Processing train: 86 - done
# Processing train: 228 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=266&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/266.csv
# Processing train: 228 - done
# Processing train: 108 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=1611&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/1611.csv
# Processing train: 108 - done
# Processing train: 36 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56801&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56801.csv
# Processing train: 36 - done
# Processing train: 26 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56755&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56755.csv
# Processing train: 26 - done
# Processing train: 26 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57016&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57016.csv
# Processing train: 26 - done
# Processing train: 12  ("ЗАХІДНИЙ ЕКСПРЕС") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56754&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56754.csv
# Processing train: 12  ("ЗАХІДНИЙ ЕКСПРЕС") - done
# Processing train: 26 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57018&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57018.csv
# Processing train: 26 - done
# Processing train: 168 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57104&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57104.csv
# Processing train: 168 - done
# Processing train: 258 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=38&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/38.csv
# Processing train: 258 - done
# Processing train: 35 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56802&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56802.csv
# Processing train: 35 - done
# Processing train: 715  (ІНТЕРСІТІ+) - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56177&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56177.csv
# Processing train: 715  (ІНТЕРСІТІ+) - done
# Processing train: 705  (ІНТЕРСІТІ+) - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=54731&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/54731.csv
# Processing train: 705  (ІНТЕРСІТІ+) - done
# Processing train: 806 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56888&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56888.csv
# Processing train: 806 - done
# Processing train: 804 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56897&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56897.csv
# Processing train: 804 - done
# Processing train: 26 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57017&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57017.csv
# Processing train: 26 - done
# Processing train: 218 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=1872&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/1872.csv
# Processing train: 218 - done
# Processing train: 16  ("ВЛАДИСЛАВ ЗУБЕНКО") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56787&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56787.csv
# Processing train: 16  ("ВЛАДИСЛАВ ЗУБЕНКО") - done
# Processing train: 606 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57121&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57121.csv
# Processing train: 606 безпересадковий вагон - done
# Processing train: 606 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=1483&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/1483.csv
# Processing train: 606 - done
# Processing train: 601 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=1375&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/1375.csv
# Processing train: 601 - done
# Processing train: 13 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56769&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56769.csv
# Processing train: 13 - done
# Processing train: 13 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57056&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57056.csv
# Processing train: 13 - done
# Processing train: 50  ("КОБЗАР") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56783&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56783.csv
# Processing train: 50  ("КОБЗАР") - done
# Processing train: 42 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=286&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/286.csv
# Processing train: 42 - done
# Processing train: 207 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=1946&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/1946.csv
# Processing train: 207 - done
# Processing train: 29 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56.csv
# Processing train: 29 - done
# Processing train: 81  ("ДЕСНА") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56970&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56970.csv
# Processing train: 81  ("ДЕСНА") - done
# Processing train: 239 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=3794&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/3794.csv
# Processing train: 239 - done
# Processing train: 81  ("ДЕСНА") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=54164&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/54164.csv
# Processing train: 81  ("ДЕСНА") - done
# Processing train: 29 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57108&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57108.csv
# Processing train: 29 - done
# Processing train: 829 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56884&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56884.csv
# Processing train: 829 - done
# Processing train: 107 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=2126&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/2126.csv
# Processing train: 107 - done
# Processing train: 45 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56975&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56975.csv
# Processing train: 45 - done
# Processing train: 45 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56760&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56760.csv
# Processing train: 45 - done
# Processing train: 601 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57062&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57062.csv
# Processing train: 601 безпересадковий вагон - done
# Processing train: 185 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56845&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56845.csv
# Processing train: 185 - done
# Processing train: 235  ("ВЕЧІРНІ ЗОРІ") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=1291&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/1291.csv
# Processing train: 235  ("ВЕЧІРНІ ЗОРІ") - done
# Processing train: 235  ("ВЕЧІРНІ ЗОРІ") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57007&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57007.csv
# Processing train: 235  ("ВЕЧІРНІ ЗОРІ") - done
# Processing train: 17  ("МРІЯ") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56789&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56789.csv
# Processing train: 17  ("МРІЯ") - done
# Processing train: 131  ("СЛОБОЖАНЩИНА") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56806&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56806.csv
# Processing train: 131  ("СЛОБОЖАНЩИНА") - done
# Processing train: 111   ("СЛОБОЖАНЩИНА") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56993&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56993.csv
# Processing train: 111   ("СЛОБОЖАНЩИНА") - done
# Processing train: 111   ("СЛОБОЖАНЩИНА") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=144&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/144.csv
# Processing train: 111   ("СЛОБОЖАНЩИНА") - done
# Processing train: 131  ("СЛОБОЖАНЩИНА") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56994&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56994.csv
# Processing train: 131  ("СЛОБОЖАНЩИНА") - done
# Processing train: 15  ("ВЛАДИСЛАВ ЗУБЕНКО") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56990&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56990.csv
# Processing train: 15  ("ВЛАДИСЛАВ ЗУБЕНКО") - done
# Processing train: 15  ("ВЛАДИСЛАВ ЗУБЕНКО") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56816&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56816.csv
# Processing train: 15  ("ВЛАДИСЛАВ ЗУБЕНКО") - done
# Processing train: 17  ("МРІЯ") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57130&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57130.csv
# Processing train: 17  ("МРІЯ") - done
# Processing train: 235  ("ВЕЧІРНІ ЗОРІ") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57008&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57008.csv
# Processing train: 235  ("ВЕЧІРНІ ЗОРІ") - done
# Processing train: 17  ("МРІЯ") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56984&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56984.csv
# Processing train: 17  ("МРІЯ") - done
# Processing train: 17  ("МРІЯ") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56788&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56788.csv
# Processing train: 17  ("МРІЯ") - done
# Processing train: 235  ("ВЕЧІРНІ ЗОРІ") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=1290&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/1290.csv
# Processing train: 235  ("ВЕЧІРНІ ЗОРІ") - done
# Processing train: 109 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=147&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/147.csv
# Processing train: 109 - done
# Processing train: 95  ("ТЯСМИН") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=411&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/411.csv
# Processing train: 95  ("ТЯСМИН") - done
# Processing train: 702 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=1281&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/1281.csv
# Processing train: 702 - done
# Processing train: 250 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56843&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56843.csv
# Processing train: 250 - done
# Processing train: 226 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57089&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57089.csv
# Processing train: 226 - done
# Processing train: 220 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56844&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56844.csv
# Processing train: 220 - done
# Processing train: 136 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57146&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57146.csv
# Processing train: 136 - done
# Processing train: 668 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=1448&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/1448.csv
# Processing train: 668 - done
# Processing train: 44 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56759&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56759.csv
# Processing train: 44 - done
# Processing train: 146 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=53&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/53.csv
# Processing train: 146 - done
# Processing train: 26 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57019&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57019.csv
# Processing train: 26 - done
# Processing train: 26 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56718&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56718.csv
# Processing train: 26 - done
# Processing train: 751 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56838&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56838.csv
# Processing train: 751 - done
# Processing train: 97 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=319&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/319.csv
# Processing train: 97 - done
# Processing train: 97 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57134&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57134.csv
# Processing train: 97 - done
# Processing train: 197 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=2223&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/2223.csv
# Processing train: 197 - done
# Processing train: 77 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56851&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56851.csv
# Processing train: 77 - done
# Processing train: 84 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=387&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/387.csv
# Processing train: 84 - done
# Processing train: 198 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=2224&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/2224.csv
# Processing train: 198 - done
# Processing train: 753 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56660&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56660.csv
# Processing train: 753 - done
# Processing train: 98 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57135&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57135.csv
# Processing train: 98 - done
# Processing train: 98 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=1479&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/1479.csv
# Processing train: 98 - done
# Processing train: 88 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56762&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56762.csv
# Processing train: 88 - done
# Processing train: 128 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=356&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/356.csv
# Processing train: 128 - done
# Processing train: 78 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56852&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56852.csv
# Processing train: 78 - done
# Processing train: 78 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=349&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/349.csv
# Processing train: 78 безпересадковий вагон - done
# Processing train: 73 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=419&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/419.csv
# Processing train: 73 безпересадковий вагон - done
# Processing train: 86 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=354&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/354.csv
# Processing train: 86 - done
# Processing train: 86 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57142&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57142.csv
# Processing train: 86 - done
# Processing train: 84 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=274&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/274.csv
# Processing train: 84 - done
# Processing train: 127 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56763&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56763.csv
# Processing train: 127 - done
# Processing train: 127 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56987&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56987.csv
# Processing train: 127 - done
# Processing train: 752 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56512&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56512.csv
# Processing train: 752 - done
# Processing train: 754 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56839&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56839.csv
# Processing train: 754 - done
# Processing train: 357  ("ГУЦУЛЬЩИНА") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=251&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/251.csv
# Processing train: 357  ("ГУЦУЛЬЩИНА") - done
# Processing train: 747  (ІНТЕРСІТІ) - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56693&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56693.csv
# Processing train: 747  (ІНТЕРСІТІ) - done
# Processing train: 358  ("ГУЦУЛЬЩИНА") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=397&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/397.csv
# Processing train: 358  ("ГУЦУЛЬЩИНА") - done
# Processing train: 748  (ІНТЕРСІТІ) - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56538&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56538.csv
# Processing train: 748  (ІНТЕРСІТІ) - done
# Processing train: 146 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=14&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/14.csv
# Processing train: 146 - done
# Processing train: 585 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57047&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57047.csv
# Processing train: 585 - done
# Processing train: 688 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56854&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56854.csv
# Processing train: 688 безпересадковий вагон - done
# Processing train: 797  ("ПІВДЕННИЙ ЕКСПРЕС") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=37561&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/37561.csv
# Processing train: 797  ("ПІВДЕННИЙ ЕКСПРЕС") - done
# Processing train: 63  ("СКІФІЯ") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=271&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/271.csv
# Processing train: 63  ("СКІФІЯ") - done
# Processing train: 618 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57138&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57138.csv
# Processing train: 618 безпересадковий вагон - done
# Processing train: 618 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=54269&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/54269.csv
# Processing train: 618 безпересадковий вагон - done
# Processing train: 763  (ІНТЕРСІТІ+) - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=290&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/290.csv
# Processing train: 763  (ІНТЕРСІТІ+) - done
# Processing train: 148 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56840&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56840.csv
# Processing train: 148 - done
# Processing train: 105  ("ЧОРНОМОРЕЦЬ") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=325&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/325.csv
# Processing train: 105  ("ЧОРНОМОРЕЦЬ") - done
# Processing train: 223 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=77&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/77.csv
# Processing train: 223 - done
# Processing train: 145 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56853&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56853.csv
# Processing train: 145 безпересадковий вагон - done
# Processing train: 145 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=12&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/12.csv
# Processing train: 145 - done
# Processing train: 642 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56823&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56823.csv
# Processing train: 642 - done
# Processing train: 92 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=314&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/314.csv
# Processing train: 92 - done
# Processing train: 564 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=54347&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/54347.csv
# Processing train: 564 безпересадковий вагон - done
# Processing train: 318  ("ТАВРІЯ") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57136&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57136.csv
# Processing train: 318  ("ТАВРІЯ") - done
# Processing train: 318  ("ТАВРІЯ") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=265&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/265.csv
# Processing train: 318  ("ТАВРІЯ") - done
# Processing train: 94 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=190&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/190.csv
# Processing train: 94 - done
# Processing train: 142 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56774&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56774.csv
# Processing train: 142 - done
# Processing train: 23 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=222&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/222.csv
# Processing train: 23 - done
# Processing train: 764  (ІНТЕРСІТІ+) - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=375&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/375.csv
# Processing train: 764  (ІНТЕРСІТІ+) - done
# Processing train: 64  ("СКІФІЯ") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=285&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/285.csv
# Processing train: 64  ("СКІФІЯ") - done
# Processing train: 224 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=78&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/78.csv
# Processing train: 224 - done
# Processing train: 106  ("ЧОРНОМОРЕЦЬ") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=173&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/173.csv
# Processing train: 106  ("ЧОРНОМОРЕЦЬ") - done
# Processing train: 148 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56834&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56834.csv
# Processing train: 148 - done
# Processing train: 642 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=403&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/403.csv
# Processing train: 642 - done
# Processing train: 64 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=54418&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/54418.csv
# Processing train: 64 безпересадковий вагон - done
# Processing train: 94 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=326&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/326.csv
# Processing train: 94 - done
# Processing train: 24 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=208&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/208.csv
# Processing train: 24 - done
# Processing train: 8 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56772&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56772.csv
# Processing train: 8 - done
# Processing train: 8 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57126&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57126.csv
# Processing train: 8 - done
# Processing train: 60  ("ЧАЙКА") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=253&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/253.csv
# Processing train: 60  ("ЧАЙКА") - done
# Processing train: 270 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57013&by_id=1
# 43  trains parsed
# ...
# 43  trains parsed
# Trains table saved to file: trains/56916.csv
# Processing train: 848 - done
# Processing train: 53  ("ЛИБІДЬ") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=54635&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/54635.csv
# Processing train: 53  ("ЛИБІДЬ") - done
# Processing train: 882 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56925&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56925.csv
# Processing train: 882 - done
# Processing train: 779  (ІНТЕРСІТІ"СТОЛИЧНИЙ ЕКСПРЕС") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=380&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/380.csv
# Processing train: 779  (ІНТЕРСІТІ"СТОЛИЧНИЙ ЕКСПРЕС") - done
# Processing train: 795  (ІНТЕРСІТІ"СТОЛИЧНИЙ ЕКСПРЕС") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57036&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57036.csv
# Processing train: 795  (ІНТЕРСІТІ"СТОЛИЧНИЙ ЕКСПРЕС") - done
# Processing train: 830 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57124&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57124.csv
# Processing train: 830 - done
# Processing train: 830 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56895&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56895.csv
# Processing train: 830 - done
# Processing train: 818 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56924&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56924.csv
# Processing train: 818 - done
# Processing train: 814 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56869&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56869.csv
# Processing train: 814 - done
# Processing train: 721  (ІНТЕРСІТІ+) - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=49123&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/49123.csv
# Processing train: 721  (ІНТЕРСІТІ+) - done
# Processing train: 775  ("СТОЛИЧНИЙ ЕКСПРЕС") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=348&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/348.csv
# Processing train: 775  ("СТОЛИЧНИЙ ЕКСПРЕС") - done
# Processing train: 63  ("ОБЕРІГ") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=1323&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/1323.csv
# Processing train: 63  ("ОБЕРІГ") - done
# Processing train: 723  (ІНТЕРСІТІ+) - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56982&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56982.csv
# Processing train: 723  (ІНТЕРСІТІ+) - done
# Processing train: 63  ("ОБЕРІГ") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56996&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56996.csv
# Processing train: 63  ("ОБЕРІГ") - done
# Processing train: 725  (ІНТЕРСІТІ+) - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56998&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56998.csv
# Processing train: 725  (ІНТЕРСІТІ+) - done
# Processing train: 775  ("СТОЛИЧНИЙ ЕКСПРЕС") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56995&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56995.csv
# Processing train: 775  ("СТОЛИЧНИЙ ЕКСПРЕС") - done
# Processing train: 721  (ІНТЕРСІТІ+) - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56989&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56989.csv
# Processing train: 721  (ІНТЕРСІТІ+) - done
# Processing train: 725  (ІНТЕРСІТІ+) - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=49127&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/49127.csv
# Processing train: 725  (ІНТЕРСІТІ+) - done
# Processing train: 163 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57098&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57098.csv
# Processing train: 163 - done
# Processing train: 723  (ІНТЕРСІТІ+) - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=49125&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/49125.csv
# Processing train: 723  (ІНТЕРСІТІ+) - done
# Processing train: 719  (ІНТЕРСІТІ+) - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56703&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56703.csv
# Processing train: 719  (ІНТЕРСІТІ+) - done
# Processing train: 719  (ІНТЕРСІТІ+) - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56997&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56997.csv
# Processing train: 719  (ІНТЕРСІТІ+) - done
# Processing train: 160 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57094&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57094.csv
# Processing train: 160 - done
# Processing train: 772 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=54482&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/54482.csv
# Processing train: 772 безпересадковий вагон - done
# Processing train: 292  ("ПОДІЛЬСЬКИЙ ЕКСПРЕС") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57116&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57116.csv
# Processing train: 292  ("ПОДІЛЬСЬКИЙ ЕКСПРЕС") - done
# Processing train: 772  ("ПОДІЛЬСЬКИЙ ЕКСПРЕС") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=53446&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/53446.csv
# Processing train: 772  ("ПОДІЛЬСЬКИЙ ЕКСПРЕС") - done
# Processing train: 177 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=54627&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/54627.csv
# Processing train: 177 - done
# Processing train: 56 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56547&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56547.csv
# Processing train: 56 - done
# Processing train: 211 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57114&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57114.csv
# Processing train: 211 - done
# Processing train: 781  ("СТОЛИЧНИЙ ЕКСПРЕС") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=320&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/320.csv
# Processing train: 781  ("СТОЛИЧНИЙ ЕКСПРЕС") - done
# Processing train: 118  ("БУКОВИНА") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56829&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56829.csv
# Processing train: 118  ("БУКОВИНА") - done
# Processing train: 860 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56898&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56898.csv
# Processing train: 860 - done
# Processing train: 842 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56889&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56889.csv
# Processing train: 842 - done
# Processing train: 816 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56868&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56868.csv
# Processing train: 816 - done
# Processing train: 830 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56875&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56875.csv
# Processing train: 830 - done
# Processing train: 784  ("ПОДІЛЬСЬКИЙ ЕКСПРЕС") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=213&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/213.csv
# Processing train: 784  ("ПОДІЛЬСЬКИЙ ЕКСПРЕС") - done
# Processing train: 778  ("ПОДІЛЬСЬКИЙ ЕКСПРЕС") - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=368&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/368.csv
# Processing train: 778  ("ПОДІЛЬСЬКИЙ ЕКСПРЕС") - done
# Processing train: 778 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=54497&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/54497.csv
# Processing train: 778 безпересадковий вагон - done
# Processing train: 53 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=154&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/154.csv
# Processing train: 53 - done
# Processing train: 53 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56973&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56973.csv
# Processing train: 53 - done
# Processing train: 143 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=421&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/421.csv
# Processing train: 143 - done
# Processing train: 143 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56978&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56978.csv
# Processing train: 143 - done
# Processing train: 61 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=54185&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/54185.csv
# Processing train: 61 - done
# Processing train: 61 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=54184&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/54184.csv
# Processing train: 61 - done
# Processing train: 890 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56926&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56926.csv
# Processing train: 890 - done
# Processing train: 887 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56915&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56915.csv
# Processing train: 887 - done
# Processing train: 879 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56876&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56876.csv
# Processing train: 879 - done
# Processing train: 369 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=17&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/17.csv
# Processing train: 369 - done
# Processing train: 788 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56937&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56937.csv
# Processing train: 788 - done
# Processing train: 92 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=54332&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/54332.csv
# Processing train: 92 безпересадковий вагон - done
# Processing train: 92 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=305&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/305.csv
# Processing train: 92 - done
# Processing train: 610 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=52668&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/52668.csv
# Processing train: 610 - done
# Processing train: 19 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56979&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56979.csv
# Processing train: 19 безпересадковий вагон - done
# Processing train: 19 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=54388&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/54388.csv
# Processing train: 19 безпересадковий вагон - done
# Processing train: 19 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=414&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/414.csv
# Processing train: 19 - done
# Processing train: 19 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57004&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57004.csv
# Processing train: 19 безпересадковий вагон - done
# Processing train: 19 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=54383&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/54383.csv
# Processing train: 19 безпересадковий вагон - done
# Processing train: 19 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=55254&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/55254.csv
# Processing train: 19 безпересадковий вагон - done
# Processing train: 19 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57005&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57005.csv
# Processing train: 19 безпересадковий вагон - done
# Processing train: 92 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=55255&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/55255.csv
# Processing train: 92 безпересадковий вагон - done
# Processing train: 118 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=54459&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/54459.csv
# Processing train: 118 безпересадковий вагон - done
# Processing train: 118 безпересадковий вагон - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57022&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57022.csv
# Processing train: 118 безпересадковий вагон - done
# Processing train: 118 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57021&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57021.csv
# Processing train: 118 - done
# Processing train: 118 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56792&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56792.csv
# Processing train: 118 - done
# Processing train: 369 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=308&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/308.csv
# Processing train: 369 - done
# Processing train: 20 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=260&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/260.csv
# Processing train: 20 - done
# Processing train: 117 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56791&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56791.csv
# Processing train: 117 - done
# Processing train: 117 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56980&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56980.csv
# Processing train: 117 - done
# Processing train: 609 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=94&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/94.csv
# Processing train: 609 - done
# Processing train: 91 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57001&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57001.csv
# Processing train: 91 - done
# Processing train: 91 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=261&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/261.csv
# Processing train: 91 - done
# Processing train: 787 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56936&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56936.csv
# Processing train: 787 - done
# Processing train: 328 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57039&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57039.csv
# Processing train: 328 - done
# Processing train: 329 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56941&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56941.csv
# Processing train: 329 - done
# Processing train: 327 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=57040&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/57040.csv
# Processing train: 327 - done
# Processing train: 330 - start
# GET url: http://www.uz.gov.ua/passengers/timetable/?ntrain=56942&by_id=1
# 43  trains parsed
# Trains table saved to file: trains/56942.csv
# Processing train: 330 - done

# %%
csv_file_name = 'trains_all.csv'
with open(csv_file_name, 'w', newline='', encoding = "utf-8") as csv_file:        
    writer = csv.writer(csv_file)
    writer.writerows(all_trains)
    print('All trains table saved to file: '+csv_file_name)
# Out:
# All trains table saved to file: trains_all.csv

# %%
stations_dup_n = 0
all_stops_list = []
all_stations_dict = {}
for key in all_stops_dict.keys():
    for stop in all_stops_dict[key]:
        station_id = stop[0]
        station_name = stop[1]
        all_stops_list.append([key, station_id, stop[2], stop[3]])
        if station_id in all_stations_dict:
            stations_dup_n = stations_dup_n + 1
        else:
            all_stations_dict[station_id] = station_name
print(stations_dup_n, ' duplications of stations in all trains, ', 
      len(all_stations_dict.keys()), 'unique stations')
# Out:
# 6872  duplications of stations in all trains,  810 unique stations

# %%
csv_file_name = 'stations_all.csv'
with open(csv_file_name, 'w', newline='', encoding = "utf-8") as csv_file:        
    writer = csv.writer(csv_file)
    for key in all_stations_dict:
        writer.writerow([key, all_stations_dict[key]])
    print('All stations table saved to file: '+csv_file_name)
# Out:
# All stations table saved to file: stations_all.csv

# %%
csv_file_name = 'stops_all.csv'
with open(csv_file_name, 'w', newline='', encoding = "utf-8") as csv_file:        
    writer = csv.writer(csv_file)
    writer.writerows(all_stops_list)
    print('All stops table saved to file: '+csv_file_name)
# Out:
# All stops table saved to file: stops_all.csv
